# %%
notebooks = [
    "./gold_dim_dates",
    "./gold_dim_locations",
    "./gold_dim_property_types",
    "./gold_fact_listings"
]

for notebook in notebooks:
    print(f"Running notebook {notebook}")
    dbutils.notebook.run(notebook, timeout_seconds=0)
